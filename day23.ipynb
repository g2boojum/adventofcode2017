# %% [markdown]
# ### puzzle 1 ###

# %%
import collections

# %%
class Registers(object):
    def __init__(self):
        self.reg = collections.defaultdict(int)
    def parse(self, y):
        try:
            return int(y)
        except ValueError:
            return self.reg[y]
    def setx(self, x, y):
        self.reg[x] = self.parse(y)
    def subx(self, x, y):
        self.reg[x] -= self.parse(y)
    def mulx(self, x, y):
        self.reg[x] *= self.parse(y)
    def jnz(self, x, y, instr_ptr):
        ck = self.parse(x)
        if ck != 0:
            return instr_ptr + self.parse(y)
        return instr_ptr + 1

# %%
def follow_instructions(instructions, dbg=True):
    registers = Registers()
    if not dbg:
        registers.reg['a'] = 1
    instr_ptr = 0
    num_muls = 0
    steps = 0
    while (0 <= instr_ptr < len(instructions)) and steps < 10_000_000:
        tokens = instructions[instr_ptr].split()
        name = tokens[0]
        if name == 'set':
            registers.setx(tokens[1], tokens[2])
        elif name == 'sub':
            registers.subx(tokens[1], tokens[2])
        elif name == 'mul':
            registers.mulx(tokens[1], tokens[2])
            num_muls += 1
        elif name == 'jnz':
            instr_ptr = registers.jnz(tokens[1], tokens[2], instr_ptr)
            steps += 1
            continue
        else:
            raise ValueError('invalid instruction')
        if dbg == False:
            if steps % 10000 == 0:
                print(registers.reg)
        instr_ptr += 1
        steps += 1
    return num_muls

# %%
puzzle_instructions = [line.strip() for line in open('day23_input').readlines()]
follow_instructions(puzzle_instructions)
# Out:
# 6724

# %% [markdown]
# ### puzzle 2 ###

# %%
follow_instructions(puzzle_instructions, dbg=False)
# Out:
# defaultdict(<class 'int'>, {'a': 1, 'b': 84})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 1251, 'g': -107149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 2501, 'g': -105899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 3751, 'g': -104649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 5001, 'g': -103399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 6251, 'g': -102149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 7501, 'g': -100899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 8751, 'g': -99649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 10001, 'g': -98399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 11251, 'g': -97149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 12501, 'g': -95899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 13751, 'g': -94649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 15001, 'g': -93399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 16251, 'g': -92149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 17501, 'g': -90899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 18751, 'g': -89649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 20001, 'g': -88399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 21251, 'g': -87149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 22501, 'g': -85899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 23751, 'g': -84649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 25001, 'g': -83399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 26251, 'g': -82149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 27501, 'g': -80899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 28751, 'g': -79649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 30001, 'g': -78399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 31251, 'g': -77149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 32501, 'g': -75899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 33751, 'g': -74649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 35001, 'g': -73399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 36251, 'g': -72149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 37501, 'g': -70899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 38751, 'g': -69649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 40001, 'g': -68399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 41251, 'g': -67149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 42501, 'g': -65899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 43751, 'g': -64649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 45001, 'g': -63399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 46251, 'g': -62149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 47501, 'g': -60899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 48751, 'g': -59649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 50001, 'g': -58399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 51251, 'g': -57149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 52501, 'g': -55899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 1, 'd': 2, 'e': 53751, 'g': -54649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 55001, 'g': 55001})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 56251, 'g': 56251})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 57501, 'g': 57501})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 58751, 'g': 58751})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 60001, 'g': 60001})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 61251, 'g': 61251})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 62501, 'g': 62501})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 63751, 'g': 63751})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 65001, 'g': 65001})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 66251, 'g': 66251})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 67501, 'g': 67501})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 68751, 'g': 68751})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 70001, 'g': 70001})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 71251, 'g': 71251})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 72501, 'g': 72501})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 73751, 'g': 73751})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 75001, 'g': 75001})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 76251, 'g': 76251})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e': 77501, 'g': 77501})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 2, 'e':

# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 2305, 'g': 2305})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 3555, 'g': 3555})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 4805, 'g': 4805})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 6055, 'g': 6055})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 7305, 'g': 7305})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 8555, 'g': 8555})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 9805, 'g': 9805})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 11055, 'g': 11055})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 12305, 'g': 12305})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 13555, 'g': 13555})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 14805, 'g': 14805})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 16055, 'g': 16055})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 17305, 'g': 17305})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 18555, 'g': 18555})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 19805, 'g': 19805})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 21055, 'g': 21055})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 22305, 'g': 3120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 23555, 'g': 9370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 24805, 'g': 15620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 26055, 'g': 21870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 27305, 'g': 28120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 28555, 'g': 34370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 29805, 'g': 40620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 31055, 'g': 46870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 32305, 'g': 53120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 33555, 'g': 59370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 34805, 'g': 65620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 36055, 'g': 71870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 37305, 'g': 78120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 38555, 'g': 84370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 39805, 'g': 90620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 41055, 'g': 96870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 42305, 'g': 103120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 43555, 'g': 109370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 44805, 'g': 115620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 46055, 'g': 121870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 47305, 'g': 128120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 48555, 'g': 134370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 49805, 'g': 140620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 51055, 'g': 146870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 52305, 'g': 153120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 53555, 'g': 159370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 54805, 'g': 165620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 56055, 'g': 171870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 57305, 'g': 178120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 58555, 'g': 184370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 59805, 'g': 190620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 61055, 'g': 196870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 62305, 'g': 203120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 63555, 'g': 209370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 64805, 'g': 215620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 66055, 'g': 221870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 67305, 'g': 228120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 68555, 'g': 234370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 69805, 'g': 240620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 71055, 'g': 246870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 72305, 'g': 253120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 73555, 'g': 259370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 74805, 'g': 265620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 76055, 'g': 271870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 77305, 'g': 278120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 78555, 'g': 284370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 79805, 'g': 290620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 81055, 'g': 296870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 82305, 'g': 303120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 83555, 'g': 309370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 84805, 'g': 315620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 86055, 'g': 321870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 87305, 'g': 328120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 88555, 'g': 334370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 89805, 'g': 340620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 91055, 'g': 346870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 92305, 'g': 353120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 93555, 'g': 359370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 94805, 'g': 365620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 96055, 'g': 371870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 97305, 'g': 378120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 98555, 'g': 384370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 99805, 'g': 390620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 101055, 'g': 396870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 102305, 'g': 403120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 103555, 'g': 409370})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 104805, 'g': 415620})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 106055, 'g': 421870})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 5, 'e': 107305, 'g': 428120})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 507, 'g': -104851})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 1757, 'g': -96101})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 3007, 'g': -87351})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 4257, 'g': -78601})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 5507, 'g': -69851})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 6757, 'g': -61101})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 8007, 'g': -52351})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 9257, 'g': -43601})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 10507, 'g': -34851})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 11757, 'g': -26101})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 13007, 'g': -17351})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 14257, 'g': -8601})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 15507, 'g': 149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 16757, 'g': 8899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 18007, 'g': 17649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 19257, 'g': 26399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 20507, 'g': 35149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 21757, 'g': 43899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 23007, 'g': 52649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 24257, 'g': 61399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 25507, 'g': 70149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 26757, 'g': 78899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 28007, 'g': 87649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 29257, 'g': 96399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 30507, 'g': 105149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 31757, 'g': 113899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 33007, 'g': 122649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 34257, 'g': 131399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 35507, 'g': 140149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 36757, 'g': 148899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 38007, 'g': 157649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 39257, 'g': 166399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 40507, 'g': 175149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 41757, 'g': 183899})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 43007, 'g': 192649})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 44257, 'g': 201399})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e': 45507, 'g': 210149})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 7, 'e':

# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 101561, 'g': 1015610})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 102811, 'g': 1028110})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 104061, 'g': 1040610})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 105311, 'g': 1053110})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 106561, 'g': 1065610})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 10, 'e': 107811, 'g': 1078110})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 663, 'g': -101118})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 1913, 'g': -87368})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 3163, 'g': -73618})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 4413, 'g': -59868})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 5663, 'g': -46118})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 6913, 'g': -32368})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 8163, 'g': -18618})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 9413, 'g': -4868})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 10663, 'g': 8882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 11913, 'g': 22632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 13163, 'g': 36382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 14413, 'g': 50132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 15663, 'g': 63882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 16913, 'g': 77632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 18163, 'g': 91382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 19413, 'g': 105132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 20663, 'g': 118882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 21913, 'g': 132632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 23163, 'g': 146382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 24413, 'g': 160132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 25663, 'g': 173882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 26913, 'g': 187632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 28163, 'g': 201382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 29413, 'g': 215132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 30663, 'g': 228882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 31913, 'g': 242632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 33163, 'g': 256382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 34413, 'g': 270132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 35663, 'g': 283882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 36913, 'g': 297632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 38163, 'g': 311382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 39413, 'g': 325132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 40663, 'g': 338882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 41913, 'g': 352632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 43163, 'g': 366382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 44413, 'g': 380132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 45663, 'g': 393882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 46913, 'g': 407632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 48163, 'g': 421382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 49413, 'g': 435132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 50663, 'g': 448882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 51913, 'g': 462632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 53163, 'g': 476382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 54413, 'g': 490132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 55663, 'g': 503882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 56913, 'g': 517632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 58163, 'g': 531382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 59413, 'g': 545132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 60663, 'g': 558882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 61913, 'g': 572632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 63163, 'g': 586382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 64413, 'g': 600132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 65663, 'g': 613882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 66913, 'g': 627632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 68163, 'g': 641382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 69413, 'g': 655132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 70663, 'g': 668882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 71913, 'g': 682632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 73163, 'g': 696382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 74413, 'g': 710132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 75663, 'g': 723882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 76913, 'g': 737632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 78163, 'g': 751382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 79413, 'g': 765132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 80663, 'g': 778882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 81913, 'g': 792632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 83163, 'g': 806382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 84413, 'g': 820132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 85663, 'g': 833882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 86913, 'g': 847632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 88163, 'g': 861382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 89413, 'g': 875132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 90663, 'g': 888882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 91913, 'g': 902632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 93163, 'g': 916382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 94413, 'g': 930132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 95663, 'g': 943882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 96913, 'g': 957632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 98163, 'g': 971382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 99413, 'g': 985132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 100663, 'g': 998882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 101913, 'g': 1012632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 103163, 'g': 1026382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 104413, 'g': 1040132})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 105663, 'g': 1053882})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 106913, 'g': 1067632})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 11, 'e': 108163, 'g': 1081382})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 115, 'g': -106905})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 1365, 'g': -90655})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 2615, 'g': -74405})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 3865, 'g': -58155})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 5115, 'g': -41905})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 6365, 'g': -25655})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 7615, 'g': -9405})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 8865, 'g': 6845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 10115, 'g': 23095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 11365, 'g': 39345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 12615, 'g': 55595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 13865, 'g': 71845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 15115, 'g': 88095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 16365, 'g': 104345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 17615, 'g': 120595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 18865, 'g': 136845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 20115, 'g': 153095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 21365, 'g': 169345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 22615, 'g': 185595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 23865, 'g': 201845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 25115, 'g': 218095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 26365, 'g': 234345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 27615, 'g': 250595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 28865, 'g': 266845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 30115, 'g': 283095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 31365, 'g': 299345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 32615, 'g': 315595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 33865, 'g': 331845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 35115, 'g': 348095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 36365, 'g': 364345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 37615, 'g': 380595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 38865, 'g': 396845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 40115, 'g': 413095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 41365, 'g': 429345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 42615, 'g': 445595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 43865, 'g': 461845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 45115, 'g': 478095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 46365, 'g': 494345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 47615, 'g': 510595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 48865, 'g': 526845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 50115, 'g': 543095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 51365, 'g': 559345})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 52615, 'g': 575595})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 53865, 'g': 591845})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 55115, 'g': 608095})
# defaultdict(<class 'int'>, {'a': 1, 'b': 108400, 'c': 125400, 'f': 0, 'd': 13, 'e': 56365, 'g': 624345})
# 1249993

# %% [markdown]
# Okay, registers 'a' and 'c',seem to stay fixed. It looks like 'b' is fixed, but that's not true since there's a 'sub b -17' instruction near the bottom of the code. The others change. In 10_000_000 steps, 'h' has not yet been seen, but the answer isn't '0', so I need to be more clever.  The 'set f 1' line in the instructions is as far back as the later jumps can go, so a and c are set before that line, and never again changed, while b,d-h are set in the rest of the code. It looks like 'b' can only ever be increased by 17. Also, 'h' only appears in 'sub h -1', so h is incremented everytime some condition is seen (everytime f is zero in 'jnz f 2', it seems), so h is counting some sort of event.

# %%
b = 84
c = b
b *= 100
b -= -100_000
c = b
c -= -17000
print(b, c)
# Out:
# 108400 125400

# %% [markdown]
# For the rest of the code, break it up by the jumps. Forward jumps are conditionals, while backwards jumps are loops.

# %% [markdown]
# ```python
# b = 108400
# c = 125400
# while True:
#     f = 1
#     d = 2
#     while True:
#         e = 2
#         while True:
#             g = d
#             g *= e
#             g -= b
#             if g == 0:
#                 f = 0
#             e -= -1
#             g = e
#             g -= b
#             if g == 0:
#                 break
#         d -= -1
#         g = d
#         g -= b
#         if g == 0:
#             break
#     if f == 0:
#         h -= -1
#     g = b
#     g -= c
#     if g == 0:
#         break
#     b -= -17
# ```
#
# That's ugly, but I can simplify it some. The end of the loop increments b by 17, so the outer loop is stepping b from a lower limit to c by increments of 17. 'f' is a boolean flag. Here's a next attempt:

# %% [markdown]
# ```python
# b = 108400
# c = 125400
# for b in range(108400, 125400, 17):
#     f = True
#     d = 2
#     while True:
#         e = 2
#         while True:
#             if d*e == b:
#                 f = False
#             e += 1
#             if e == b:
#                 break
#         d += 1
#         if d == b:
#             break
#     if f == 0:
#         h -= -1
# ```

# %% [markdown]
# It looks like e goes from 2 to b, and d goes from 2 to b, both incremented by 1 each time, so those are for loops:
#
# ```python
# b = 108400
# c = 125400
# for b in range(108400, 125400, 17):
#     f = True
#     for d in range(2, b):
#         for e in range(2, b):
#             if d*e == b:
#                 f = False
#     if f == False:
#         h += 1
# ```
#
# So, if b is the product of two integers, then increment h. Okay, that's counting non-prime numbers, in a rather inefficient manner. I'm stealing the non_primes function from nedbat, because I'm lazy.

# %%
import math
b = 108400
c = 125400
step = 17
def non_primes():
    for num in range(b, c+1, step):
        for factor in range(2, int(math.sqrt(num)) + 1):
            if num % factor == 0:
                yield num
                break

# %%
num_non_primes = 0
for non_prime in non_primes():
    num_non_primes += 1
print(num_non_primes)
# Out:
# 903
