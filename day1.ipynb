# %% [markdown]
# ### puzzle 1 ###

# %%
digits = open('day1_input').read().strip()
digits
# Out:
# '...'

# %%
inside = sum(int(d) for i,d in enumerate(digits[:-1]) if d == digits[i+1])
if digits[0] == digits[-1]:
    print(inside + int(digits[0]))
else:
    print(inside)
# Out:
# 1182

# %% [markdown]
# ### puzzle 2 ###

# %%
N = len(digits)
def idx(i):
    return i % N

# %%
N
# Out:
# 2000

# %%
sum(int(d) for i,d in enumerate(digits) if d == digits[idx(i+N//2)])
# Out:
# 1152
